# %% [markdown]
# # classificaton terrorist vs counter-terrorist

# %% [markdown]
# **The images can be downloaded here:** (no link yet)

# %% [markdown]
# ## Prapare variable

# %%
# Розмір міні-вибірки
batch_size = 16
# Кількість епох для навчання
epochs = 10
# Розмір зображеннь
img_width, img_height = 150, 150
img_size = (img_width, img_height)
# Кількість каналів в зображенні
img_channels = 3
Image_rgb_size = (img_width, img_height, img_channels)

# Кількість класів зображень
nb_classes = 2
# Назви класів
classes = ['CT', 'T']

# Частина набору даних для тестування
test_data_portion = 0.1
# Частина набору даних для перевірки
val_data_portion = 0.1

# Каталог з набором даних
dataset_dir = 'dataset'

# Каталог з даними для навчання
train_dir = 'train'
# Каталог з даними для перевірки
val_dir = 'val'
# Каталог з даними длятестування
test_dir = 'test'

nb_images = 0
import os
for root, _, files in os.walk(dataset_dir):
    nb_images += len(files)
print(nb_images)

nb_train_samples = nb_images * (1 - test_data_portion - val_data_portion)
nb_test_samples = nb_images * test_data_portion
nb_val_samples = nb_images * val_data_portion
nb_train_samples, nb_val_samples, nb_test_samples
# Out:
# 64
# (51.2, 6.4, 6.4)

# %% [markdown]
# ## Prapare data

# %% [markdown]
# ### Create folder

# %%
import shutil, os

def create_directory(dir_name):
    if os.path.exists(dir_name):
        shutil.rmtree(dir_name)
    os.makedirs(dir_name)
    [os.makedirs(os.path.join(dir_name, cl)) for cl in classes]

# %%
create_directory(train_dir)
create_directory(val_dir)
create_directory(test_dir)

# %% [markdown]
# ### Find and remove corrupted image

# %%
import os
from PIL import Image
count = 0

for root, _, files in os.walk(dataset_dir):
    for filename in files:
        if filename.endswith('.jpg'):
            try:
                img = Image.open(os.path.join(root, filename))
                img.verify()
                img.close()
            except(IOError, SyntaxError)as e:
                print('Bad file to delete :  '+root+"\\"+filename)
                count = count+1
                os.remove(os.path.join(root, filename))
print("Count of corrupted image:", count)
# Out:
# Count of corrupted image: 0

# %% [markdown]
# ### train \ val \ test split

# %%
import shutil
import os
from glob import glob


def copy_images(list_files_to_copy, dest_dir):
    for img in list_files_to_copy:
        shutil.copy2(
            img,
            os.path.join(dest_dir)
        )


def train_val_test_split(from_dir):
    list_train = []
    list_val = []
    list_test = []
    list_images = glob(from_dir+"/*.jpg") + glob(from_dir+"/*.png")
    end_train_index = round(
        len(list_images) * (1 - val_data_portion - test_data_portion))
    for i in range(end_train_index):
        list_train.append(list_images[i])

    end_val_index = round(len(list_images) * (1 - test_data_portion))
    for i in range(end_train_index, end_val_index):
        list_val.append(list_images[i])

    for i in range(end_val_index, len(list_images)):
        list_test.append(list_images[i])

    return list_train, list_val, list_test

# %%
dirs = [train_dir, val_dir, test_dir]

for mylist, dir in zip(train_val_test_split(dataset_dir+"/CT"), dirs):
    copy_images(mylist, dir + "\\" + classes[0])

for mylist, dir in zip(train_val_test_split(dataset_dir+"/T"), dirs):
    copy_images(mylist, dir + "\\" + classes[1])

# %% [markdown]
# ## Створюємо нейронну мережу

# %% [markdown]
# ### DataGenerator

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary'
)
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary'
)
test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# Found 52 images belonging to 2 classes.
# Found 6 images belonging to 2 classes.
# Found 6 images belonging to 2 classes.

# %% [markdown]
# ### Create model on InceptionV3

# %%
from keras.applications.inception_v3 import InceptionV3
inception_v3 = InceptionV3(weights='imagenet',
              include_top=False,
              input_shape=Image_rgb_size)
inception_v3.trainable = False
inception_v3.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 150, 150, 3  0           []
#                                 )]
#
#  conv2d_846 (Conv2D)            (None, 74, 74, 32)   864         ['input_10[0][0]']
#
#  batch_normalization_846 (Batch  (None, 74, 74, 32)  96          ['conv2d_846[0][0]']
#  Normalization)
#
#  activation_846 (Activation)    (None, 74, 74, 32)   0           ['batch_normalization_846[0][0]']
#
#  conv2d_847 (Conv2D)            (None, 72, 72, 32)   9216        ['activation_846[0][0]']
#
#  batch_normalization_847 (Batch  (None, 72, 72, 32)  96          ['conv2d_847[0][0]']
#  Normalization)
#
#  activation_847 (Activation)    (None, 72, 72, 32)   0           ['batch_normalization_847[0][0]']
#
#  conv2d_848 (Conv2D)            (None, 72, 72, 64)   18432       ['activation_847[0][0]']
#
#  batch_normalization_848 (Batch  (None, 72, 72, 64)  192         ['conv2d_848[0][0]']
#  Normalization)
#
#  activation_848 (Activation)    (None, 72, 72, 64)   0           ['batch_normalization_848[0][0]']
#
#  max_pooling2d_36 (MaxPooling2D  (None, 35, 35, 64)  0           ['activation_848[0][0]']
#  )
#
#  conv2d_849 (Conv2D)            (None, 35, 35, 80)   5120        ['max_pooling2d_36[0][0]']
#
#  batch_normalization_849 (Batch  (None, 35, 35, 80)  240         ['conv2d_849[0][0]']
#  Normalization)
#
#  activation_849 (Activation)    (None, 35, 35, 80)   0           ['batch_normalization_849[0][0]']
#
#  conv2d_850 (Conv2D)            (None, 33, 33, 192)  138240      ['activation_849[0][0]']
#
#  batch_normalization_850 (Batch  (None, 33, 33, 192)  576        ['conv2d_850[0][0]']
#  Normalization)
#
#  activation_850 (Activation)    (None, 33, 33, 192)  0           ['batch_normalization_850[0][0]']
#
#  max_pooling2d_37 (MaxPooling2D  (None, 16, 16, 192)  0          ['activation_850[0][0]']
#  )
#
#  conv2d_854 (Conv2D)            (None, 16, 16, 64)   12288       ['max_pooling2d_37[0][0]']
#
#  batch_normalization_854 (Batch  (None, 16, 16, 64)  192         ['conv2d_854[0][0]']
#  Normalization)
#
#  activation_854 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_854[0][0]']
#
#  conv2d_852 (Conv2D)            (None, 16, 16, 48)   9216        ['max_pooling2d_37[0][0]']
#
#  conv2d_855 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_854[0][0]']
#
#  batch_normalization_852 (Batch  (None, 16, 16, 48)  144         ['conv2d_852[0][0]']
#  Normalization)
#
#  batch_normalization_855 (Batch  (None, 16, 16, 96)  288         ['conv2d_855[0][0]']
#  Normalization)
#
#  activation_852 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_852[0][0]']
#
#  activation_855 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_855[0][0]']
#
#  average_pooling2d_81 (AverageP  (None, 16, 16, 192)  0          ['max_pooling2d_37[0][0]']
#  ooling2D)
#
#  conv2d_851 (Conv2D)            (None, 16, 16, 64)   12288       ['max_pooling2d_37[0][0]']
#
#  conv2d_853 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_852[0][0]']
#
#  conv2d_856 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_855[0][0]']
#
#  conv2d_857 (Conv2D)            (None, 16, 16, 32)   6144        ['average_pooling2d_81[0][0]']
#
#  batch_normalization_851 (Batch  (None, 16, 16, 64)  192         ['conv2d_851[0][0]']
#  Normalization)
#
#  batch_normalization_853 (Batch  (None, 16, 16, 64)  192         ['conv2d_853[0][0]']
#  Normalization)
#
#  batch_normalization_856 (Batch  (None, 16, 16, 96)  288         ['conv2d_856[0][0]']
#  Normalization)
#
#  batch_normalization_857 (Batch  (None, 16, 16, 32)  96          ['conv2d_857[0][0]']
#  Normalization)
#
#  activation_851 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_851[0][0]']
#
#  activation_853 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_853[0][0]']
#
#  activation_856 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_856[0][0]']
#
#  activation_857 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_857[0][0]']
#
#  mixed0 (Concatenate)           (None, 16, 16, 256)  0           ['activation_851[0][0]',
#                                                                   'activation_853[0][0]',
#                                                                   'activation_856[0][0]',
#                                                                   'activation_857[0][0]']
#
#  conv2d_861 (Conv2D)            (None, 16, 16, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_861 (Batch  (None, 16, 16, 64)  192         ['conv2d_861[0][0]']
#  Normalization)
#
#  activation_861 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_861[0][0]']
#
#  conv2d_859 (Conv2D)            (None, 16, 16, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_862 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_861[0][0]']
#
#  batch_normalization_859 (Batch  (None, 16, 16, 48)  144         ['conv2d_859[0][0]']
#  Normalization)
#
#  batch_normalization_862 (Batch  (None, 16, 16, 96)  288         ['conv2d_862[0][0]']
#  Normalization)
#
#  activation_859 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_859[0][0]']
#
#  activation_862 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_862[0][0]']
#
#  average_pooling2d_82 (AverageP  (None, 16, 16, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_858 (Conv2D)            (None, 16, 16, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_860 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_859[0][0]']
#
#  conv2d_863 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_862[0][0]']
#
#  conv2d_864 (Conv2D)            (None, 16, 16, 64)   16384       ['average_pooling2d_82[0][0]']
#
#  batch_normalization_858 (Batch  (None, 16, 16, 64)  192         ['conv2d_858[0][0]']
#  Normalization)
#
#  batch_normalization_860 (Batch  (None, 16, 16, 64)  192         ['conv2d_860[0][0]']
#  Normalization)
#
#  batch_normalization_863 (Batch  (None, 16, 16, 96)  288         ['conv2d_863[0][0]']
#  Normalization)
#
#  batch_normalization_864 (Batch  (None, 16, 16, 64)  192         ['conv2d_864[0][0]']
#  Normalization)
#
#  activation_858 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_858[0][0]']
#
#  activation_860 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_860[0][0]']
#
#  activation_863 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_863[0][0]']
#
#  activation_864 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_864[0][0]']
#
#  mixed1 (Concatenate)           (None, 16, 16, 288)  0           ['activation_858[0][0]',
#                                                                   'activation_860[0][0]',
#                                                                   'activation_863[0][0]',
#                                                                   'activation_864[0][0]']
#
#  conv2d_868 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_868 (Batch  (None, 16, 16, 64)  192         ['conv2d_868[0][0]']
#  Normalization)
#
#  activation_868 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_868[0][0]']
#
#  conv2d_866 (Conv2D)            (None, 16, 16, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_869 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_868[0][0]']
#
#  batch_normalization_866 (Batch  (None, 16, 16, 48)  144         ['conv2d_866[0][0]']
#  Normalization)
#
#  batch_normalization_869 (Batch  (None, 16, 16, 96)  288         ['conv2d_869[0][0]']
#  Normalization)
#
#  activation_866 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_866[0][0]']
#
#  activation_869 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_869[0][0]']
#
#  average_pooling2d_83 (AverageP  (None, 16, 16, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_865 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_867 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_866[0][0]']
#
#  conv2d_870 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_869[0][0]']
#
#  conv2d_871 (Conv2D)            (None, 16, 16, 64)   18432       ['average_pooling2d_83[0][0]']
#
#  batch_normalization_865 (Batch  (None, 16, 16, 64)  192         ['conv2d_865[0][0]']
#  Normalization)
#
#  batch_normalization_867 (Batch  (None, 16, 16, 64)  192         ['conv2d_867[0][0]']
#  Normalization)
#
#  batch_normalization_870 (Batch  (None, 16, 16, 96)  288         ['conv2d_870[0][0]']
#  Normalization)
#
#  batch_normalization_871 (Batch  (None, 16, 16, 64)  192         ['conv2d_871[0][0]']
#  Normalization)
#
#  activation_865 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_865[0][0]']
#
#  activation_867 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_867[0][0]']
#
#  activation_870 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_870[0][0]']
#
#  activation_871 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_871[0][0]']
#
#  mixed2 (Concatenate)           (None, 16, 16, 288)  0           ['activation_865[0][0]',
#                                                                   'activation_867[0][0]',
#                                                                   'activation_870[0][0]',
#                                                                   'activation_871[0][0]']
#
#  conv2d_873 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_873 (Batch  (None, 16, 16, 64)  192         ['conv2d_873[0][0]']
#  Normalization)
#
#  activation_873 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_873[0][0]']
#
#  conv2d_874 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_873[0][0]']
#
#  batch_normalization_874 (Batch  (None, 16, 16, 96)  288         ['conv2d_874[0][0]']
#  Normalization)
#
#  activation_874 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_874[0][0]']
#
#  conv2d_872 (Conv2D)            (None, 7, 7, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_875 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_874[0][0]']
#
#  batch_normalization_872 (Batch  (None, 7, 7, 384)   1152        ['conv2d_872[0][0]']
#  Normalization)
#
#  batch_normalization_875 (Batch  (None, 7, 7, 96)    288         ['conv2d_875[0][0]']
#  Normalization)
#
#  activation_872 (Activation)    (None, 7, 7, 384)    0           ['batch_normalization_872[0][0]']
#
#  activation_875 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_875[0][0]']
#
#  max_pooling2d_38 (MaxPooling2D  (None, 7, 7, 288)   0           ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 7, 7, 768)    0           ['activation_872[0][0]',
#                                                                   'activation_875[0][0]',
#                                                                   'max_pooling2d_38[0][0]']
#
#  conv2d_880 (Conv2D)            (None, 7, 7, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_880 (Batch  (None, 7, 7, 128)   384         ['conv2d_880[0][0]']
#  Normalization)
#
#  activation_880 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_880[0][0]']
#
#  conv2d_881 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_880[0][0]']
#
#  batch_normalization_881 (Batch  (None, 7, 7, 128)   384         ['conv2d_881[0][0]']
#  Normalization)
#
#  activation_881 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_881[0][0]']
#
#  conv2d_877 (Conv2D)            (None, 7, 7, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_882 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_881[0][0]']
#
#  batch_normalization_877 (Batch  (None, 7, 7, 128)   384         ['conv2d_877[0][0]']
#  Normalization)
#
#  batch_normalization_882 (Batch  (None, 7, 7, 128)   384         ['conv2d_882[0][0]']
#  Normalization)
#
#  activation_877 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_877[0][0]']
#
#  activation_882 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_882[0][0]']
#
#  conv2d_878 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_877[0][0]']
#
#  conv2d_883 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_882[0][0]']
#
#  batch_normalization_878 (Batch  (None, 7, 7, 128)   384         ['conv2d_878[0][0]']
#  Normalization)
#
#  batch_normalization_883 (Batch  (None, 7, 7, 128)   384         ['conv2d_883[0][0]']
#  Normalization)
#
#  activation_878 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_878[0][0]']
#
#  activation_883 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_883[0][0]']
#
#  average_pooling2d_84 (AverageP  (None, 7, 7, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_876 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_879 (Conv2D)            (None, 7, 7, 192)    172032      ['activation_878[0][0]']
#
#  conv2d_884 (Conv2D)            (None, 7, 7, 192)    172032      ['activation_883[0][0]']
#
#  conv2d_885 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_84[0][0]']
#
#  batch_normalization_876 (Batch  (None, 7, 7, 192)   576         ['conv2d_876[0][0]']
#  Normalization)
#
#  batch_normalization_879 (Batch  (None, 7, 7, 192)   576         ['conv2d_879[0][0]']
#  Normalization)
#
#  batch_normalization_884 (Batch  (None, 7, 7, 192)   576         ['conv2d_884[0][0]']
#  Normalization)
#
#  batch_normalization_885 (Batch  (None, 7, 7, 192)   576         ['conv2d_885[0][0]']
#  Normalization)
#
#  activation_876 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_876[0][0]']
#
#  activation_879 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_879[0][0]']
#
#  activation_884 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_884[0][0]']
#
#  activation_885 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_885[0][0]']
#
#  mixed4 (Concatenate)           (None, 7, 7, 768)    0           ['activation_876[0][0]',
#                                                                   'activation_879[0][0]',
#                                                                   'activation_884[0][0]',
#                                                                   'activation_885[0][0]']
#
#  conv2d_890 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_890 (Batch  (None, 7, 7, 160)   480         ['conv2d_890[0][0]']
#  Normalization)
#
#  activation_890 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_890[0][0]']
#
#  conv2d_891 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_890[0][0]']
#
#  batch_normalization_891 (Batch  (None, 7, 7, 160)   480         ['conv2d_891[0][0]']
#  Normalization)
#
#  activation_891 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_891[0][0]']
#
#  conv2d_887 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_892 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_891[0][0]']
#
#  batch_normalization_887 (Batch  (None, 7, 7, 160)   480         ['conv2d_887[0][0]']
#  Normalization)
#
#  batch_normalization_892 (Batch  (None, 7, 7, 160)   480         ['conv2d_892[0][0]']
#  Normalization)
#
#  activation_887 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_887[0][0]']
#
#  activation_892 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_892[0][0]']
#
#  conv2d_888 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_887[0][0]']
#
#  conv2d_893 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_892[0][0]']
#
#  batch_normalization_888 (Batch  (None, 7, 7, 160)   480         ['conv2d_888[0][0]']
#  Normalization)
#
#  batch_normalization_893 (Batch  (None, 7, 7, 160)   480         ['conv2d_893[0][0]']
#  Normalization)
#
#  activation_888 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_888[0][0]']
#
#  activation_893 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_893[0][0]']
#
#  average_pooling2d_85 (AverageP  (None, 7, 7, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_886 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_889 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_888[0][0]']
#
#  conv2d_894 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_893[0][0]']
#
#  conv2d_895 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_85[0][0]']
#
#  batch_normalization_886 (Batch  (None, 7, 7, 192)   576         ['conv2d_886[0][0]']
#  Normalization)
#
#  batch_normalization_889 (Batch  (None, 7, 7, 192)   576         ['conv2d_889[0][0]']
#  Normalization)
#
#  batch_normalization_894 (Batch  (None, 7, 7, 192)   576         ['conv2d_894[0][0]']
#  Normalization)
#
#  batch_normalization_895 (Batch  (None, 7, 7, 192)   576         ['conv2d_895[0][0]']
#  Normalization)
#
#  activation_886 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_886[0][0]']
#
#  activation_889 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_889[0][0]']
#
#  activation_894 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_894[0][0]']
#
#  activation_895 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_895[0][0]']
#
#  mixed5 (Concatenate)           (None, 7, 7, 768)    0           ['activation_886[0][0]',
#                                                                   'activation_889[0][0]',
#                                                                   'activation_894[0][0]',
#                                                                   'activation_895[0][0]']
#
#  conv2d_900 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_900 (Batch  (None, 7, 7, 160)   480         ['conv2d_900[0][0]']
#  Normalization)
#
#  activation_900 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_900[0][0]']
#
#  conv2d_901 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_900[0][0]']
#
#  batch_normalization_901 (Batch  (None, 7, 7, 160)   480         ['conv2d_901[0][0]']
#  Normalization)
#
#  activation_901 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_901[0][0]']
#
#  conv2d_897 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_902 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_901[0][0]']
#
#  batch_normalization_897 (Batch  (None, 7, 7, 160)   480         ['conv2d_897[0][0]']
#  Normalization)
#
#  batch_normalization_902 (Batch  (None, 7, 7, 160)   480         ['conv2d_902[0][0]']
#  Normalization)
#
#  activation_897 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_897[0][0]']
#
#  activation_902 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_902[0][0]']
#
#  conv2d_898 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_897[0][0]']
#
#  conv2d_903 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_902[0][0]']
#
#  batch_normalization_898 (Batch  (None, 7, 7, 160)   480         ['conv2d_898[0][0]']
#  Normalization)
#
#  batch_normalization_903 (Batch  (None, 7, 7, 160)   480         ['conv2d_903[0][0]']
#  Normalization)
#
#  activation_898 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_898[0][0]']
#
#  activation_903 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_903[0][0]']
#
#  average_pooling2d_86 (AverageP  (None, 7, 7, 768)   0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_896 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_899 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_898[0][0]']
#
#  conv2d_904 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_903[0][0]']
#
#  conv2d_905 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_86[0][0]']
#
#  batch_normalization_896 (Batch  (None, 7, 7, 192)   576         ['conv2d_896[0][0]']
#  Normalization)
#
#  batch_normalization_899 (Batch  (None, 7, 7, 192)   576         ['conv2d_899[0][0]']
#  Normalization)
#
#  batch_normalization_904 (Batch  (None, 7, 7, 192)   576         ['conv2d_904[0][0]']
#  Normalization)
#
#  batch_normalization_905 (Batch  (None, 7, 7, 192)   576         ['conv2d_905[0][0]']
#  Normalization)
#
#  activation_896 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_896[0][0]']
#
#  activation_899 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_899[0][0]']
#
#  activation_904 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_904[0][0]']
#
#  activation_905 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_905[0][0]']
#
#  mixed6 (Concatenate)           (None, 7, 7, 768)    0           ['activation_896[0][0]',
#                                                                   'activation_899[0][0]',
# ...
#  mixed8 (Concatenate)           (None, 3, 3, 1280)   0           ['activation_917[0][0]',
#                                                                   'activation_921[0][0]',
#                                                                   'max_pooling2d_39[0][0]']
#
#  conv2d_926 (Conv2D)            (None, 3, 3, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_926 (Batch  (None, 3, 3, 448)   1344        ['conv2d_926[0][0]']
#  Normalization)
#
#  activation_926 (Activation)    (None, 3, 3, 448)    0           ['batch_normalization_926[0][0]']
#
#  conv2d_923 (Conv2D)            (None, 3, 3, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_927 (Conv2D)            (None, 3, 3, 384)    1548288     ['activation_926[0][0]']
#
#  batch_normalization_923 (Batch  (None, 3, 3, 384)   1152        ['conv2d_923[0][0]']
#  Normalization)
#
#  batch_normalization_927 (Batch  (None, 3, 3, 384)   1152        ['conv2d_927[0][0]']
#  Normalization)
#
#  activation_923 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_923[0][0]']
#
#  activation_927 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_927[0][0]']
#
#  conv2d_924 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_923[0][0]']
#
#  conv2d_925 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_923[0][0]']
#
#  conv2d_928 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_927[0][0]']
#
#  conv2d_929 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_927[0][0]']
#
#  average_pooling2d_88 (AverageP  (None, 3, 3, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_922 (Conv2D)            (None, 3, 3, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_924 (Batch  (None, 3, 3, 384)   1152        ['conv2d_924[0][0]']
#  Normalization)
#
#  batch_normalization_925 (Batch  (None, 3, 3, 384)   1152        ['conv2d_925[0][0]']
#  Normalization)
#
#  batch_normalization_928 (Batch  (None, 3, 3, 384)   1152        ['conv2d_928[0][0]']
#  Normalization)
#
#  batch_normalization_929 (Batch  (None, 3, 3, 384)   1152        ['conv2d_929[0][0]']
#  Normalization)
#
#  conv2d_930 (Conv2D)            (None, 3, 3, 192)    245760      ['average_pooling2d_88[0][0]']
#
#  batch_normalization_922 (Batch  (None, 3, 3, 320)   960         ['conv2d_922[0][0]']
#  Normalization)
#
#  activation_924 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_924[0][0]']
#
#  activation_925 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_925[0][0]']
#
#  activation_928 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_928[0][0]']
#
#  activation_929 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_929[0][0]']
#
#  batch_normalization_930 (Batch  (None, 3, 3, 192)   576         ['conv2d_930[0][0]']
#  Normalization)
#
#  activation_922 (Activation)    (None, 3, 3, 320)    0           ['batch_normalization_922[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 3, 3, 768)    0           ['activation_924[0][0]',
#                                                                   'activation_925[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 3, 3, 768)    0           ['activation_928[0][0]',
#                                                                   'activation_929[0][0]']
#
#  activation_930 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_930[0][0]']
#
#  mixed9 (Concatenate)           (None, 3, 3, 2048)   0           ['activation_922[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_18[0][0]',
#                                                                   'activation_930[0][0]']
#
#  conv2d_935 (Conv2D)            (None, 3, 3, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_935 (Batch  (None, 3, 3, 448)   1344        ['conv2d_935[0][0]']
#  Normalization)
#
#  activation_935 (Activation)    (None, 3, 3, 448)    0           ['batch_normalization_935[0][0]']
#
#  conv2d_932 (Conv2D)            (None, 3, 3, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_936 (Conv2D)            (None, 3, 3, 384)    1548288     ['activation_935[0][0]']
#
#  batch_normalization_932 (Batch  (None, 3, 3, 384)   1152        ['conv2d_932[0][0]']
#  Normalization)
#
#  batch_normalization_936 (Batch  (None, 3, 3, 384)   1152        ['conv2d_936[0][0]']
#  Normalization)
#
#  activation_932 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_932[0][0]']
#
#  activation_936 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_936[0][0]']
#
#  conv2d_933 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_932[0][0]']
#
#  conv2d_934 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_932[0][0]']
#
#  conv2d_937 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_936[0][0]']
#
#  conv2d_938 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_936[0][0]']
#
#  average_pooling2d_89 (AverageP  (None, 3, 3, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_931 (Conv2D)            (None, 3, 3, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_933 (Batch  (None, 3, 3, 384)   1152        ['conv2d_933[0][0]']
#  Normalization)
#
#  batch_normalization_934 (Batch  (None, 3, 3, 384)   1152        ['conv2d_934[0][0]']
#  Normalization)
#
#  batch_normalization_937 (Batch  (None, 3, 3, 384)   1152        ['conv2d_937[0][0]']
#  Normalization)
#
#  batch_normalization_938 (Batch  (None, 3, 3, 384)   1152        ['conv2d_938[0][0]']
#  Normalization)
#
#  conv2d_939 (Conv2D)            (None, 3, 3, 192)    393216      ['average_pooling2d_89[0][0]']
#
#  batch_normalization_931 (Batch  (None, 3, 3, 320)   960         ['conv2d_931[0][0]']
#  Normalization)
#
#  activation_933 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_933[0][0]']
#
#  activation_934 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_934[0][0]']
#
#  activation_937 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_937[0][0]']
#
#  activation_938 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_938[0][0]']
#
#  batch_normalization_939 (Batch  (None, 3, 3, 192)   576         ['conv2d_939[0][0]']
#  Normalization)
#
#  activation_931 (Activation)    (None, 3, 3, 320)    0           ['batch_normalization_931[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 3, 3, 768)    0           ['activation_933[0][0]',
#                                                                   'activation_934[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 3, 3, 768)    0           ['activation_937[0][0]',
#                                                                   'activation_938[0][0]']
#
#  activation_939 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_939[0][0]']
#
#  mixed10 (Concatenate)          (None, 3, 3, 2048)   0           ['activation_931[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_19[0][0]',
#                                                                   'activation_939[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout

model = Sequential()
model.add(inception_v3)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
from keras.optimizers import Adam
model.compile(loss='binary_crossentropy',
              optimizer=Adam(learning_rate=1e-5),
              metrics=['accuracy'])

# %%
print(model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 3, 3, 2048)        21802784
#
#  flatten_4 (Flatten)         (None, 18432)             0
#
#  dense_8 (Dense)             (None, 256)               4718848
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 26,521,889
# Trainable params: 4,719,105
# Non-trainable params: 21,802,784
# _________________________________________________________________
# None

# %% [markdown]
# ### Навчаємо нейронну мережу

# %%
history = model.fit(
    train_generator,
    epochs = epochs,
    validation_data=val_generator,
    steps_per_epoch=nb_train_samples//batch_size,
    validation_steps=nb_val_samples//batch_size)
# Out:
# Epoch 1/5
# WARNING:tensorflow:5 out of the last 17 calls to <function Model.make_train_function.<locals>.train_function at 0x000002C3F0556280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s - loss: 1.5075 - accuracy: 0.5500
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [86], line 1
# ----> 1 history = model.fit(
#       2     train_generator,
#       3     epochs = epochs,
#       4     validation_data=val_generator,
#       5     steps_per_epoch=nb_train_samples//batch_size,
#       6     validation_steps=nb_val_samples//batch_size)
#
# File c:\Users\Kolyanys\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\Kolyanys\AppData\Local\Programs\Python\Python39\lib\contextlib.py:117, in _GeneratorContextManager.__enter__(self)
#     115 del self.args, self.kwds, self.func
#     116 try:
# --> 117     return next(self.gen)
#     118 except StopIteration:
#     119     raise RuntimeError("generator didn't yield") from None
#
# TypeError: Cannot convert 0.0 to EagerTensor of dtype int64

# %% [markdown]
# ## Оцінюємо якість  навчання мережі

# %%
# Оцінюємо якість навчання моделі на тестових даних 
scores = model.evaluate(test_generator)
print("Точність роботи на тестових даних: %.2f%%" % (scores[1]*100))
# Out:
# 1/1 [==============================] - 0s 383ms/step - loss: 0.6609 - accuracy: 0.5000
# Точність роботи на тестових даних: 50.00%

# %%
import matplotlib.pyplot as plt
history_dict = history.history
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)
plt.plot(epochs, acc_values, 'bo', label='Training acc')
plt.plot(epochs, val_acc_values, 'b', label='Validation acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Зберігаємо навчену нейрону мережу

# %%
model.save("ct_vs_t_inception_v3.h5")
